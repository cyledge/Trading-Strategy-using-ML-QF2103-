# %% [markdown]
# # Setup
# import data, and package

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
import numpy.random as npr
import matplotlib as mpl
import matplotlib.pyplot as plt
import math
import scipy.stats as scs
import scipy.optimize as sco
import scipy.interpolate as spi
import statsmodels.api as sm
from itertools import product
import pymc as pm
from sklearn.datasets import make_blobs
from sklearn.datasets import make_classification
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import preprocessing
from mpl_toolkits.mplot3d import Axes3D
import yfinance as yf
import statsmodels.api as sm
from sklearn.ensemble import GradientBoostingClassifier

# %%
raw = pd.read_csv('tr_eikon_eod_data.csv',
                 index_col = 0, parse_dates = True)
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2216 entries, 2010-01-01 to 2018-06-29
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL.O  2138 non-null   float64
#  1   MSFT.O  2138 non-null   float64
#  2   INTC.O  2138 non-null   float64
#  3   AMZN.O  2138 non-null   float64
#  4   GS.N    2138 non-null   float64
#  5   SPY     2138 non-null   float64
#  6   .SPX    2138 non-null   float64
#  7   .VIX    2138 non-null   float64
#  8   EUR=    2216 non-null   float64
#  9   XAU=    2211 non-null   float64
#  10  GDX     2138 non-null   float64
#  11  GLD     2138 non-null   float64
# dtypes: float64(12)
# memory usage: 225.1 KB

# %%
vol = pd.DataFrame()
raw1 = yf.download(['AAPL', 'MSFT', 'INTC', 'AMZN', 'GS'], start = '2010-01-01', end= '2018-06-30')
vol['AAPL.O'] = raw1['Volume']['AAPL']
vol['MSFT.O'] = raw1['Volume']['MSFT']
vol['INTC.O'] = raw1['Volume']['INTC']
vol['AMZN.O'] = raw1['Volume']['AMZN']
vol['GS.N'] = raw1['Volume']['GS']
vol
# Out:
# [*********************100%%**********************]  5 of 5 completed
#                AAPL.O    MSFT.O    INTC.O     AMZN.O      GS.N
# Date
# 2010-01-04  493729600  38409100  47800900  151998000   9135000
# 2010-01-05  601904800  49749600  52357700  177038000  11659400
# 2010-01-06  552160000  58182400  40037400  143576000   7381100
# 2010-01-07  477131200  50559700  54041500  220604000   8727400
# 2010-01-08  447610800  51197400  48234700  196610000   7268100
# ...               ...       ...       ...        ...       ...
# 2018-06-25  126652400  35433300  45356500  150224000   3817700
# 2018-06-26   98276800  26897200  37543000   87732000   2692900
# 2018-06-27  101141200  31298400  33338800   97444000   3104200
# 2018-06-28   69460800  26650700  29055700   90594000   3072600
# 2018-06-29   90950800  28053200  28906500   90870000   3393700
#
# [2138 rows x 5 columns]

# %%
open = pd.DataFrame()
raw1 = yf.download(['AAPL', 'MSFT', 'INTC', 'AMZN', 'GS'], start = '2010-01-01', end= '2018-06-30')
open['AAPL.O'] = raw1['Open']['AAPL']
open['MSFT.O'] = raw1['Open']['MSFT']
open['INTC.O'] = raw1['Open']['INTC']
open['AMZN.O'] = raw1['Open']['AMZN']
open['GS.N'] = raw1['Open']['GS']
open
# Out:
# [*********************100%%**********************]  5 of 5 completed
#                AAPL.O      MSFT.O     INTC.O     AMZN.O        GS.N
# Date
# 2010-01-04   7.622500   30.620001  20.790001   6.812500  170.050003
# 2010-01-05   7.664286   30.850000  20.940001   6.671500  173.000000
# 2010-01-06   7.656429   30.879999  20.809999   6.730000  175.380005
# 2010-01-07   7.562500   30.629999  20.730000   6.600500  174.320007
# 2010-01-08   7.510714   30.280001  20.540001   6.528000  176.330002
# ...               ...         ...        ...        ...         ...
# 2018-06-25  45.849998  100.000000  51.169998  85.125504  224.500000
# 2018-06-26  45.747501   98.820000  49.950001  83.618500  221.779999
# 2018-06-27  46.307499   99.580002  49.340000  85.405502  221.479996
# 2018-06-28  46.025002   97.379997  48.580002  83.626999  220.250000
# 2018-06-29  46.572498   98.930000  49.529999  85.849998  224.399994
#
# [2138 rows x 5 columns]

# %%
data = raw[['AAPL.O', 'MSFT.O', 'INTC.O', 'AMZN.O', 'GS.N']]
data.dropna(inplace=True)
data
# Out:
# <ipython-input-10-4539df8019ef>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
#                 AAPL.O  MSFT.O  INTC.O   AMZN.O    GS.N
# Date
# 2010-01-04   30.572827  30.950   20.88   133.90  173.08
# 2010-01-05   30.625684  30.960   20.87   134.69  176.14
# 2010-01-06   30.138541  30.770   20.80   132.25  174.26
# 2010-01-07   30.082827  30.452   20.60   130.00  177.67
# 2010-01-08   30.282827  30.660   20.83   133.52  174.31
# ...                ...     ...     ...      ...     ...
# 2018-06-25  182.170000  98.390   50.71  1663.15  221.54
# 2018-06-26  184.430000  99.080   49.67  1691.09  221.58
# 2018-06-27  184.160000  97.540   48.76  1660.51  220.18
# 2018-06-28  185.500000  98.630   49.25  1701.45  223.42
# 2018-06-29  185.110000  98.610   49.71  1699.80  220.57
#
# [2138 rows x 5 columns]

# %%
delta = data.diff()
gain = delta.clip(lower=0)
loss = -delta.clip(upper=0)
average_gain = gain.rolling(window=14, min_periods=14).mean()
average_loss = loss.rolling(window=14, min_periods=14).mean()
RS = average_gain / average_loss
RSI = 100 - (100 / (1 + RS))
RSI
# Out:
#                AAPL.O     MSFT.O     INTC.O     AMZN.O       GS.N
# Date
# 2010-01-04        NaN        NaN        NaN        NaN        NaN
# 2010-01-05        NaN        NaN        NaN        NaN        NaN
# 2010-01-06        NaN        NaN        NaN        NaN        NaN
# 2010-01-07        NaN        NaN        NaN        NaN        NaN
# 2010-01-08        NaN        NaN        NaN        NaN        NaN
# ...               ...        ...        ...        ...        ...
# 2018-06-25  16.036585  32.789855  22.390892  40.836829  33.669549
# 2018-06-26  23.457476  35.083115  16.787004  48.882494  18.621096
# 2018-06-27  23.788050  35.299296  17.158672  43.812062  11.311953
# 2018-06-28  32.101617  37.179487  22.380952  53.254306  25.479587
# 2018-06-29  32.250580  39.048474  26.941515  52.016769  19.928826
#
# [2138 rows x 5 columns]

# %%
stock = 'GS.N'
GS = data[['GS.N']]

# %%
GS = pd.merge(GS, vol['GS.N'], left_index=True, right_index=True, how='left')
GS = GS.rename(columns={'GS.N_x': stock, "GS.N_y": "vol"})
GS
# Out:
#               GS.N       vol
# Date
# 2010-01-04  173.08   9135000
# 2010-01-05  176.14  11659400
# 2010-01-06  174.26   7381100
# 2010-01-07  177.67   8727400
# 2010-01-08  174.31   7268100
# ...            ...       ...
# 2018-06-25  221.54   3817700
# 2018-06-26  221.58   2692900
# 2018-06-27  220.18   3104200
# 2018-06-28  223.42   3072600
# 2018-06-29  220.57   3393700
#
# [2138 rows x 2 columns]

# %%
GS = pd.merge(GS, open[stock], left_index=True, right_index=True, how='left')
GS = GS.rename(columns={'GS.N_x': stock, "GS.N_y": "open"})
GS
# Out:
#               GS.N       vol        open
# Date
# 2010-01-04  173.08   9135000  170.050003
# 2010-01-05  176.14  11659400  173.000000
# 2010-01-06  174.26   7381100  175.380005
# 2010-01-07  177.67   8727400  174.320007
# 2010-01-08  174.31   7268100  176.330002
# ...            ...       ...         ...
# 2018-06-25  221.54   3817700  224.500000
# 2018-06-26  221.58   2692900  221.779999
# 2018-06-27  220.18   3104200  221.479996
# 2018-06-28  223.42   3072600  220.250000
# 2018-06-29  220.57   3393700  224.399994
#
# [2138 rows x 3 columns]

# %%
EWM = data.ewm(alpha=0.75 , min_periods = 20 , adjust = False).mean()
GS = pd.merge(GS, EWM[stock], left_index=True, right_index=True, how='left')
GS = GS.rename(columns={'GS.N_x': 'close', "GS.N_y": "EWM"})
GS
# Out:
#              close       vol        open         EWM
# Date
# 2010-01-04  173.08   9135000  170.050003         NaN
# 2010-01-05  176.14  11659400  173.000000         NaN
# 2010-01-06  174.26   7381100  175.380005         NaN
# 2010-01-07  177.67   8727400  174.320007         NaN
# 2010-01-08  174.31   7268100  176.330002         NaN
# ...            ...       ...         ...         ...
# 2018-06-25  221.54   3817700  224.500000  222.738311
# 2018-06-26  221.58   2692900  221.779999  221.869578
# 2018-06-27  220.18   3104200  221.479996  220.602394
# 2018-06-28  223.42   3072600  220.250000  222.715599
# 2018-06-29  220.57   3393700  224.399994  221.106400
#
# [2138 rows x 4 columns]

# %%
GS = pd.merge(GS, RSI[stock], left_index=True, right_index=True, how='left')
GS = GS.rename(columns={stock: "RSI"})
GS['return'] = np.log(GS['close'] / GS['close'].shift(1))
GS
# Out:
#              close       vol        open         EWM        RSI    return
# Date
# 2010-01-04  173.08   9135000  170.050003         NaN        NaN       NaN
# 2010-01-05  176.14  11659400  173.000000         NaN        NaN  0.017525
# 2010-01-06  174.26   7381100  175.380005         NaN        NaN -0.010731
# 2010-01-07  177.67   8727400  174.320007         NaN        NaN  0.019379
# 2010-01-08  174.31   7268100  176.330002         NaN        NaN -0.019093
# ...            ...       ...         ...         ...        ...       ...
# 2018-06-25  221.54   3817700  224.500000  222.738311  33.669549 -0.020020
# 2018-06-26  221.58   2692900  221.779999  221.869578  18.621096  0.000181
# 2018-06-27  220.18   3104200  221.479996  220.602394  11.311953 -0.006338
# 2018-06-28  223.42   3072600  220.250000  222.715599  25.479587  0.014608
# 2018-06-29  220.57   3393700  224.399994  221.106400  19.928826 -0.012838
#
# [2138 rows x 6 columns]

# %%
GS['PnL'] = np.where(GS['return'] > 0, 1, -1)
GS['RSI bin'] = pd.cut(GS['RSI'], bins=20, labels = False)
GS['RSI bin'] += 1

# %%
def prepare_dataframe_for_lstm(df, lag_num):
    df = df.copy()

    for i in range(lag_num, 0, -1):
        df[f'close lag{i}'] = df['close'].shift(i)

    df.dropna(inplace=True)

    return df

lag_num = 10
GS_lag = prepare_dataframe_for_lstm(GS, lag_num)
GS_lag
# Out:
#              close       vol        open         EWM        RSI    return  \
# Date
# 2010-02-01  153.13  12980800  149.820007  152.287042  27.768396  0.029222
# 2010-02-02  156.94  17246600  153.649994  155.776760  36.897881  0.024576
# 2010-02-03  157.23  16785200  157.919998  156.866690  35.404339  0.001846
# 2010-02-04  150.68  18895000  155.270004  152.226673  30.835302 -0.042551
# 2010-02-05  154.16  18759200  150.820007  153.676668  38.176760  0.022833
# ...            ...       ...         ...         ...        ...       ...
# 2018-06-25  221.54   3817700  224.500000  222.738311  33.669549 -0.020020
# 2018-06-26  221.58   2692900  221.779999  221.869578  18.621096  0.000181
# 2018-06-27  220.18   3104200  221.479996  220.602394  11.311953 -0.006338
# 2018-06-28  223.42   3072600  220.250000  222.715599  25.479587  0.014608
# 2018-06-29  220.57   3393700  224.399994  221.106400  19.928826 -0.012838
#
#             PnL  RSI bin  close lag10  close lag9  close lag8  close lag7  \
# Date
# 2010-02-01    1      6.0       165.21      166.86      167.79      160.87
# 2010-02-02    1      8.0       166.86      167.79      160.87      154.12
# 2010-02-03    1      7.0       167.79      160.87      154.12      154.98
# 2010-02-04   -1      6.0       160.87      154.12      154.98      150.88
# 2010-02-05    1      8.0       154.12      154.98      150.88      151.50
# ...         ...      ...          ...         ...         ...         ...
# 2018-06-25   -1      7.0       234.09      232.63      233.83      233.65
# 2018-06-26    1      3.0       232.63      233.83      233.65      231.92
# 2018-06-27   -1      2.0       233.83      233.65      231.92      231.39
# 2018-06-28    1      5.0       233.65      231.92      231.39      228.32
# 2018-06-29   -1      4.0       231.92      231.39      228.32      227.82
#
#             close lag6  close lag5  close lag4  close lag3  close lag2  \
# Date
# 2010-02-01      154.12      154.98      150.88      151.50      153.29
# 2010-02-02      154.98      150.88      151.50      153.29      148.72
# 2010-02-03      150.88      151.50      153.29      148.72      153.13
# 2010-02-04      151.50      153.29      148.72      153.13      156.94
# 2010-02-05      153.29      148.72      153.13      156.94      157.23
# ...                ...         ...         ...         ...         ...
# 2018-06-25      231.92      231.39      228.32      227.82      226.98
# 2018-06-26      231.39      228.32      227.82      226.98      226.02
# 2018-06-27      228.32      227.82      226.98      226.02      221.54
# 2018-06-28      227.82      226.98      226.02      221.54      221.58
# 2018-06-29      226.98      226.02      221.54      221.58      220.18
#
#             close lag1
# Date
# 2010-02-01      148.72
# 2010-02-02      153.13
# 2010-02-03      156.94
# 2010-02-04      157.23
# 2010-02-05      150.68
# ...                ...
# 2018-06-25      226.02
# 2018-06-26      221.54
# 2018-06-27      221.58
# 2018-06-28      220.18
# 2018-06-29      223.42
#
# [2119 rows x 18 columns]

# %% [markdown]
# we got these predictors

# %%
GS_lag.columns
# Out:
# Index(['close', 'vol', 'open', 'EWM', 'RSI', 'return', 'PnL', 'RSI bin',
#        'close lag10', 'close lag9', 'close lag8', 'close lag7', 'close lag6',
#        'close lag5', 'close lag4', 'close lag3', 'close lag2', 'close lag1'],
#       dtype='object')

# %% [markdown]
# After testing, using the below predictors gave the best performance

# %%
from sklearn.preprocessing import MinMaxScaler

GS_scale = GS_lag[['close', 'close lag10', 'close lag7',
       'close lag5', 'close lag3', 'close lag2', 'close lag1']]

scaler = MinMaxScaler(feature_range=(-1, 1))
GS_scale = scaler.fit_transform(GS_scale)

GS_scale # numpy
# Out:
# array([[-0.29523912, -0.16512279, -0.21186988, ..., -0.31279621,
#         -0.29351573, -0.3427402 ],
#        [-0.25420078, -0.14735028, -0.28457561, ..., -0.29351573,
#         -0.3427402 , -0.29523912],
#        [-0.25107712, -0.13733305, -0.27531237, ..., -0.3427402 ,
#         -0.29523912, -0.25420078],
#        ...,
#        [ 0.42697113,  0.57399828,  0.5477165 , ...,  0.48987505,
#          0.44161999,  0.44205084],
#        [ 0.46186988,  0.57205946,  0.51464886, ...,  0.44161999,
#          0.44205084,  0.42697113],
#        [ 0.43117191,  0.55342525,  0.50926325, ...,  0.44205084,
#          0.42697113,  0.46186988]])

# %% [markdown]
# # Split training and testing data

# %%
X = GS_scale[:, 1:] # predictors
y = GS_scale[:, 0] # to be predicted

split_index = 1600 # around 2000 in total around 80%

X_train = X[:split_index]
X_test = X[split_index:]

y_train = y[:split_index]
y_test = y[split_index:]

# %%
num_predict = 6

X_train = X_train.reshape((-1, num_predict, 1)) # LSTM model require such 3D dimension, 10 is for the dimension of our predictor
X_test = X_test.reshape((-1, num_predict, 1))

y_train = y_train.reshape((-1, 1))
y_test = y_test.reshape((-1, 1))

X_train.shape, X_test.shape, y_train.shape, y_test.shape

X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()

# %% [markdown]
# # Setup LSTM model

# %%
from torch.utils.data import Dataset # pytorch setup

class TimeSeriesDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]

train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_test, y_test)

# %%
from torch.utils.data import DataLoader

batch_size = 16

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
for _, batch in enumerate(train_loader): # not necessary, just for visualization
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([16, 6, 1]) torch.Size([16, 1])

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers,
                            batch_first=True)

        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)
        c0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

model = LSTM(1, 8, 1) # (1, 4, 1), 4 and last 1 can change
model.to(device)
model
# Out:
# LSTM(
#   (lstm): LSTM(1, 8, batch_first=True)
#   (fc): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
def train_one_epoch(): # training
    model.train(True)
    print(f'Epoch: {epoch + 1}')
    running_loss = 0.0

    for batch_index, batch in enumerate(train_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)
        x_batch = x_batch.float()
        y_batch = y_batch.float()
        #print(x_batch.dtype)
        output = model(x_batch)
        loss = loss_function(output, y_batch)
        running_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch_index % 100 == 99:  # print every 100 batches
            avg_loss_across_batches = running_loss / 100
            print('Batch {0}, Loss: {1:.3f}'.format(batch_index+1,
                                                    avg_loss_across_batches))
            running_loss = 0.0
    print()

# %%
def validate_one_epoch(): # testing
    model.train(False)
    running_loss = 0.0

    for batch_index, batch in enumerate(test_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)
        x_batch = x_batch.float()
        y_batch = y_batch.float()

        with torch.no_grad():
            output = model(x_batch)
            loss = loss_function(output, y_batch)
            running_loss += loss.item()

    avg_loss_across_batches = running_loss / len(test_loader)

    print('Val Loss: {0:.3f}'.format(avg_loss_across_batches))
    print('***************************************************')
    print()

# %% [markdown]
# after testing with differnet learning rate and epochs this give a better result
# I have thought of using for loop to test for the optimal parameter, yet, it would give a horrible time complexity

# %% [markdown]
# ## Training

# %%
# hyper-parameter - can be adjusted
learning_rate = 0.001
num_epochs = 50
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    train_one_epoch()
    validate_one_epoch()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.138
#
# Val Loss: 0.379
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.023
#
# Val Loss: 0.111
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.003
#
# Val Loss: 0.092
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.003
#
# Val Loss: 0.083
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.002
#
# Val Loss: 0.076
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.002
#
# Val Loss: 0.070
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.002
#
# Val Loss: 0.063
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.002
#
# Val Loss: 0.057
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.002
#
# Val Loss: 0.054
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.002
#
# Val Loss: 0.048
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.002
#
# Val Loss: 0.045
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.002
#
# Val Loss: 0.040
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.002
#
# Val Loss: 0.036
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.002
#
# Val Loss: 0.034
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.002
#
# Val Loss: 0.030
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.002
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.001
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.001
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.001
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.001
#
# Val Loss: 0.018
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.001
#
# Val Loss: 0.017
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.001
#
# Val Loss: 0.015
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.001
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.001
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.001
#
# Val Loss: 0.012
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.001
#
# Val Loss: 0.010
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.001
#
# Val Loss: 0.008
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.001
#
# Val Loss: 0.007
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.001
#
# Val Loss: 0.007
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.001
#
# Val Loss: 0.006
# ***************************************************
#
# Epoch: 31
# Batch 100, Loss: 0.001
#
# Val Loss: 0.006
# ***************************************************
#
# Epoch: 32
# Batch 100, Loss: 0.001
#
# Val Loss: 0.005
# ***************************************************
#
# Epoch: 33
# Batch 100, Loss: 0.001
#
# Val Loss: 0.006
# ***************************************************
#
# Epoch: 34
# Batch 100, Loss: 0.001
#
# Val Loss: 0.005
# ***************************************************
#
# Epoch: 35
# Batch 100, Loss: 0.001
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 36
# Batch 100, Loss: 0.001
#
# Val Loss: 0.005
# ***************************************************
#
# Epoch: 37
# Batch 100, Loss: 0.001
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 38
# Batch 100, Loss: 0.001
#
# Val Loss: 0.004
# ***************************************************
#
# Epoch: 39
# Batch 100, Loss: 0.001
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 40
# Batch 100, Loss: 0.001
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 41
# Batch 100, Loss: 0.001
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 42
# Batch 100, Loss: 0.001
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 43
# Batch 100, Loss: 0.001
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 44
# Batch 100, Loss: 0.001
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 45
# Batch 100, Loss: 0.001
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 46
# Batch 100, Loss: 0.001
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 47
# Batch 100, Loss: 0.001
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 48
# Batch 100, Loss: 0.001
#
# Val Loss: 0.002
# ***************************************************
#
# Epoch: 49
# Batch 100, Loss: 0.001
#
# Val Loss: 0.003
# ***************************************************
#
# Epoch: 50
# Batch 100, Loss: 0.001
#
# Val Loss: 0.002
# ***************************************************

# %% [markdown]
# # Result

# %% [markdown]
# plotting graph graph of training data, with normalized price

# %%
# havent un-normalize
with torch.no_grad():
    predicted = model(X_train.to(device)).to('cpu').numpy()

plt.plot(y_train, label='Actual Close')
plt.plot(predicted, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()

# %% [markdown]
# un-normalize price

# %%
train_predictions = predicted.flatten()

dummies = np.zeros((X_train.shape[0], num_predict + 1)) # 10 is number of predictor
dummies[:, 0] = train_predictions
dummies = scaler.inverse_transform(dummies)

train_predictions = dummies[:, 0].copy()
train_predictions
# Out:
# array([150.50715301, 152.29235352, 155.85914658, ..., 157.59593971,
#        157.35322354, 156.26663959])

# %%
dummies = np.zeros((X_train.shape[0], num_predict + 1))
dummies[:, 0] = y_train.flatten()
dummies = scaler.inverse_transform(dummies)

new_y_train = dummies[:, 0].copy()
new_y_train
# Out:
# array([153.13000003, 156.939999  , 157.23000059, ..., 157.05999994,
#        155.16999954, 154.63999882])

# %%
# un-normalized
plt.plot(new_y_train, label='Actual Close')
plt.plot(train_predictions, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()

# %% [markdown]
# model on testing data

# %%
test_predictions = model(X_test.to(device)).detach().cpu().numpy().flatten()

dummies = np.zeros((X_test.shape[0], num_predict + 1))
dummies[:, 0] = test_predictions
dummies = scaler.inverse_transform(dummies)

test_predictions = dummies[:, 0].copy()
test_predictions
# Out:
# array([155.37943884, 154.19446995, 151.50702533, 149.64877174,
#        147.38921457, 146.58230773, 146.83426518, 146.37580959,
#        147.62647175, 148.66700843, 148.93221078, 151.94479042,
#        146.20095866, 141.55917337, 141.9353678 , 144.62802793,
#        148.0716935 , 148.97107115, 146.75960179, 146.27052828,
#        147.12761466, 149.94933439, 152.35203719, 156.23325481,
#        158.54730366, 162.10497442, 162.97394995, 163.99740688,
#        163.12779221, 162.66203768, 161.46424168, 161.02281882,
#        161.08906268, 161.51825608, 161.64363025, 161.32480917,
#        160.04992603, 159.05497316, 157.33487657, 158.13257534,
#        158.56059283, 161.30630726, 163.13104325, 164.01633627,
#        163.49321254, 164.13348736, 164.17694209, 165.53400337,
#        166.26627172, 166.42785009, 166.69116821, 166.84409741,
#        166.94903011, 166.81514235, 166.2200792 , 166.35909669,
#        166.50943613, 167.16287146, 169.10559137, 170.00425518,
#        169.59306289, 169.71325475, 169.91877065, 170.22297171,
#        171.60214011, 170.2100035 , 171.01636527, 168.87804029,
#        167.17728673, 167.95060127, 167.04638164, 166.78465446,
#        166.84058628, 167.33774729, 168.26592506, 166.64746032,
#        163.46863187, 163.03819615, 163.56736544, 160.93136344,
#        161.10943775, 161.44831018, 162.39848715, 165.52200632,
#        167.38110933, 169.79820803, 171.39549533, 170.5775294 ,
#        170.21449963, 168.77052336, 170.19924599, 170.01430713,
#        172.05612723, 174.3778527 , 175.14151889, 175.42209107,
#        175.67563392, 176.10953373, 177.21480911, 178.09427653,
#        178.02389346, 178.55664997, 178.69641727, 177.7391544 ,
#        177.00393659, 176.5668466 , 180.06558075, 182.03677706,
#        189.3877243 , 197.74471912, 202.78480873, 207.41216906,
#        210.29519107, 208.35418107, 209.14892484, 210.12711614,
#        261.00999984, 258.96999756, 257.72000221, 255.95      ,
#        256.4999995 , 254.76000097, 255.67000055, 253.29000251,
#        256.83000141, 255.51999867, 251.80999912, 253.94000141,
#        254.32999965, 255.13000044, 257.03000022, 258.46000114,
#        253.65000258, 250.97000078, 256.12000065, 261.52000179,
#        260.09000087, 265.68000144, 269.03000092, 268.14000012,
#        272.47999981, 268.9400009 , 267.88999884, 272.22999853,
#        260.0399984 , 249.10999855, 258.6999975 , 257.10000147,
#        246.35000165, 249.29999797, 253.1599994 , 255.52999806,
#        262.57999771, 267.68000064, 267.61999878, 264.89000005,
#        263.39999727, 261.43000177, 266.77000106, 271.26000262,
#        267.93000192, 262.9299984 , 256.77999894, 258.11999984,
#        263.11999783, 266.93000232, 265.34999953, 266.33999974,
#        270.76999945, 273.38      , 268.52999836, 264.43000056,
#        266.60999979, 267.6       , 262.53000077, 263.18999907,
#        261.84999817, 252.60000051, 245.26000203, 254.87999915,
#        247.26000123, 249.36999922, 251.86000159, 247.35000125,
#        250.58000255, 252.61999929, 255.80999751, 249.97000119,
#        252.18999797, 256.57000074, 252.94000182, 259.58999831,
#        255.92000183, 257.87999794, 253.62999827, 253.99999774,
#        254.16999839, 251.96000099, 246.66999864, 242.49000022,
#        239.23000076, 240.08999786, 239.79999903, 238.33000057,
#        236.67000267, 234.05000273, 233.40999768, 234.939998  ,
#        237.19999787, 236.99999905, 241.73000252, 243.43999734,
#        242.92000154, 243.91000175, 241.56000186, 240.95999989,
#        239.09999765, 236.99999905, 237.70000043, 237.99999865,
#        237.80999923, 236.09999886, 235.00999925, 227.03000124,
#        229.15999801, 225.87999977, 228.34999784, 229.88999755,
#        228.33999845, 232.22999804, 233.45000076, 233.3899989 ,
#        234.09000028, 232.6300012 , 233.82999961, 233.64999957,
#        231.92000044, 231.38999971, 228.31999967, 227.82000264,
#        226.97999877, 226.01999949, 221.54000008, 221.5800004 ,
#        220.18000041, 223.42000109, 220.56999865])

# %% [markdown]
# The model can predict the general trend especially in the earlier period

# %%
plt.plot(new_y_test, label='Actual Close')
plt.plot(test_predictions, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()

# %% [markdown]
# This streategy is to compare the new predicted price with yesterday closing price

# %%
LSTM_ret = pd.DataFrame()
LSTM_ret['actual'] = new_y_test
LSTM_ret['predicted'] = test_predictions
LSTM_ret['return'] = np.log(LSTM_ret['actual'] / LSTM_ret['actual'].shift(1))
LSTM_ret['pos'] = np.where(LSTM_ret['predicted'] > LSTM_ret['actual'].shift(1), 1, -1)
LSTM_ret['lag'] = LSTM_ret['actual'].shift(1)
LSTM_ret['lag pos'] = np.where(LSTM_ret['lag'] < LSTM_ret['actual'], 1, -1)
LSTM_ret
# Out:
#          actual   predicted    return  pos         lag  lag pos
# 0    153.170000  155.379439       NaN   -1         NaN       -1
# 1    149.889999  154.194470 -0.021647    1  153.170000       -1
# 2    148.629999  151.507025 -0.008442    1  149.889999       -1
# 3    146.189999  149.648772 -0.016553    1  148.629999       -1
# 4    146.160001  147.389215 -0.000205    1  146.189999       -1
# ..          ...         ...       ...  ...         ...      ...
# 514  221.540000  226.105791 -0.020020    1  226.019999       -1
# 515  221.580000  223.165033  0.000181    1  221.540000        1
# 516  220.180000  221.929849 -0.006338    1  221.580000       -1
# 517  223.420001  220.721644  0.014608    1  220.180000        1
# 518  220.569999  222.181093 -0.012838   -1  223.420001       -1
#
# [519 rows x 6 columns]

# %%
LSTM_ret['actual'].shift(1)
# Out:
# 0             NaN
# 1      153.170000
# 2      149.889999
# 3      148.629999
# 4      146.189999
#           ...
# 514    226.019999
# 515    221.540000
# 516    221.580000
# 517    220.180000
# 518    223.420001
# Name: actual, Length: 519, dtype: float64

# %% [markdown]
# The overall return is generally sloping upward, showing that the model consistently provides a positive return

# %%
(LSTM_ret['return'] * LSTM_ret['pos']).cumsum().apply(np.exp).plot()
# Out:
# <Axes: >

# %%
(LSTM_ret['return'] * LSTM_ret['pos']).cumsum().apply(np.exp)
# Out:
# 0           NaN
# 1      0.978586
# 2      0.970360
# 3      0.954430
# 4      0.954234
#          ...
# 514    1.974360
# 515    1.974716
# 516    1.962240
# 517    1.991114
# 518    2.016842
# Length: 519, dtype: float64

# %%
LSTM_ret['return'].cumsum().apply(np.exp)
# Out:
# 0           NaN
# 1      0.978586
# 2      0.970360
# 3      0.954430
# 4      0.954234
#          ...
# 514    1.446367
# 515    1.446628
# 516    1.437488
# 517    1.458641
# 518    1.440034
# Name: return, Length: 519, dtype: float64

# %%
LSTM_ret['return'].cumsum().apply(np.exp).plot()
# Out:
# <Axes: >

# %% [markdown]
# Let's try using strategy two which is also reasonable, using new (today) predicted price to compare with yesterday predicted price
# \n Long if today predicted price > ysd predicted price
# \n Unfortunately, this strategy has a poor performance

# %%
# strategy 2
LSTM_ret = pd.DataFrame()
LSTM_ret['actual'] = new_y_test
LSTM_ret['predicted'] = test_predictions
LSTM_ret['ysd predict'] = LSTM_ret['predicted'].shift(1)
LSTM_ret['return'] = np.log(LSTM_ret['actual'] / LSTM_ret['actual'].shift(1))
LSTM_ret['pos'] = np.where(LSTM_ret['predicted'] > LSTM_ret['ysd predict'], 1, -1)
LSTM_ret['lag'] = LSTM_ret['actual'].shift(1)
LSTM_ret
# Out:
#          actual   predicted  ysd predict    return  pos         lag
# 0    153.170000  155.379439          NaN       NaN   -1         NaN
# 1    149.889999  154.194470   155.379439 -0.021647   -1  153.170000
# 2    148.629999  151.507025   154.194470 -0.008442   -1  149.889999
# 3    146.189999  149.648772   151.507025 -0.016553   -1  148.629999
# 4    146.160001  147.389215   149.648772 -0.000205   -1  146.189999
# ..          ...         ...          ...       ...  ...         ...
# 514  221.540000  226.105791   226.908454 -0.020020   -1  226.019999
# 515  221.580000  223.165033   226.105791  0.000181   -1  221.540000
# 516  220.180000  221.929849   223.165033 -0.006338   -1  221.580000
# 517  223.420001  220.721644   221.929849  0.014608   -1  220.180000
# 518  220.569999  222.181093   220.721644 -0.012838    1  223.420001
#
# [519 rows x 6 columns]

# %%
(LSTM_ret['return'] * LSTM_ret['pos']).cumsum().apply(np.exp).plot()
# Out:
# <Axes: >
